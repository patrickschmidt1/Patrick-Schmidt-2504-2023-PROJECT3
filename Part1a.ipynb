# %% [markdown]
# # MATH2504 2023 Project 3

# %% [markdown]
# ## Task 1a

# %% [markdown]
# Student name: Patrick Schmidt \
# Student number: 47447806

# %% [markdown]
# [Click here](https://github.com/patrickschmidt1/Patrick-Schmidt-2504-2023-PROJECT3) for github repo

# %%
include("C:\\Users\\patsc\\OneDrive\\yr2sem2\\MATH2504\\PROJECT3\\Patrick-Schmidt-2504-2023-PROJECT3\\Helper_func.jl");
read_file();

# %% [markdown]
# ### Task 1.1a

# %%
roomcount = combine(groupby(df, :Rooms), nrow => :Count)
# Out:
# 12×2 DataFrame
#  Row │ Rooms  Count
#      │ Int64  Int64
# ─────┼──────────────
#    1 │     1   1479
#    2 │     2   8332
#    3 │     3  15084
#    4 │     4   7956
#    5 │     5   1737
#    6 │     6    204
#    7 │     7     32
#    8 │     8     19
#    9 │     9      4
#   10 │    10      6
#   11 │    12      3
#   12 │    16      1

# %%
bar(roomcount.Rooms, roomcount.Count,fillcolor = :cyan, label=false, xlabel="Number of rooms", ylabel="Count", formatter=:plain)
